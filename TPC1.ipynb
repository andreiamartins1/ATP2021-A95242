# %%
# -*- coding: utf-8 -*-
"""
TPC1
"21 Fósforos"

A95242, Andreia Martins
"""

def fosforo ():
    n=21
    comecar= input ("Bem vindo ao jogo dos 21 fósforos! Pretende jogar primeiro? Sim (S) ou Não (N)? ")
    if (comecar=="S"):
        while n>1:
            jogar= int(input("Quantos fósforos quer tirar? 1,2,3 ou 4? "))
            if (jogar>=1 and jogar<=4):
                n=n-jogar
                print ("Restam", n ,"fósforos")
                j= 5-jogar
                n=n-j
                print ("A jogada do computador é tirar", j, "fósforos. Restam", n, "fósforos." )
            else:
                print ("Erro! Só pode tirar 1, 2, 3 ou 4 fósforos!")
        print (" Fim do jogo! O computador ganhou!!!")
    elif (comecar=="N"):
        jogadacomputador= 1
        print("O computador retirou", jogadacomputador,"fósforos")
        n=n-jogadacomputador
        print ("Restam",n,"fósforos.")
        
        while n>5:
            jogador= int(input("Quantos fósforos quer tirar? 1,2,3 ou 4? "))
            if (jogador>=1 and jogador<=4):
                n=n-jogador
                print ("Restam", n, "fósforos.")
                if (jogadacomputador + jogador < 5):
                    comp= 5-(jogadacomputador + jogador)
                    n=n-comp
                    print ("A jogada do computador é tirar", comp, "fósforos. Restam", n, "fósforos.")
                else:
                    print("O computador retirou", jogadacomputador,"fósforos")
                    n=n-jogadacomputador
                    print ("Restam",n,"fósforos.")
            else:
                print ("Erro!")
        if (n==5):
            jogadacomputador= 4
            n= n-jogadacomputador
            print ("Restam", n, "fósforos.")
            print ( "Fim do jogo! O computador ganhou!")
        elif (n==4):
            jogadacomputador= 3
            n= n-jogadacomputador
            print ("Restam", n, "fósforos.")
            print ( "Fim do jogo! O computador ganhou!")
        elif (n==3):
            jogadacomputador= 2
            n= n-jogadacomputador
            print ("Restam", n, "fósforos.")
            print ( "Fim do jogo! O computador ganhou!")
        elif (n==2):
            jogadacomputador= 1
            n= n-jogadacomputador
            print ("Restam", n, "fósforos.")
            print ( "Fim do jogo! O computador ganhou!")
    
fosforo ()
